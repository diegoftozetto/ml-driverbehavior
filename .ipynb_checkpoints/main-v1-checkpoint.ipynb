# %% [markdown]
# # <font color='black'>Driver Behavior TPIIS</font>

# %%
'''
Bibliotecas e Módulos
'''
#Bibliotecas
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn
import pickle

#Módulos
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

#Módulos (Algoritmos - ML)
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### <font color='black'>1 - Carregar Dataset</font>
# #### <u>Link do Dataset: https://data.mendeley.com/datasets/jj3tw8kj6h/2</u>

# %%
'''
Dataset
'''
#Carregar Dataset
dat = pd.read_csv('db_w14.csv')
print("=== (linhas, colunas) ===")
print(dat.shape)
print("")

# Verificar as 5 primeiras linhas
print("=== 5 primeiras linhas do Dataset ===")
print(dat.head())

#Número de casos por classe
print("")
print("=== Número de casos por classe ===")
print("")
for i in range(1, 5):
    Class = len(dat.loc[dat['Class'] == i])
    print("Classe "+str(i)+": "+str(Class))
# Out:
# === (linhas, colunas) ===
# (1101, 31)
#
# === 5 primeiras linhas do Dataset ===
#    Class     GyroX     GyroY     GyroZ      AccX      AccY      AccZ  \
# 0      1 -1.358779  5.564885  0.198473  0.512207 -0.186523 -0.977783
# 1      1  1.282443  0.404580  1.198473  0.577393 -0.297363 -0.860840
# 2      1 -0.236641  0.732824  1.450382  0.347168 -0.072510 -1.052246
# 3      1 -0.847328  2.030534  0.694656  0.490479 -0.109619 -0.966064
# 4      1  1.770992  8.526718  1.946565  0.455322 -0.253174 -0.851318
#
#    GyroMeanX  GyroMeanY  GyroMeanZ    ...     AccMeanZ   AccMinX   AccMinY  \
# 0  -0.211559   4.349509  -0.019629    ...    -0.958583  0.158936 -0.257568
# 1  -0.053980   4.114504   0.007088    ...    -0.950823  0.158936 -0.297363
# 2  -0.005998   3.842966   0.051254    ...    -0.953613  0.158936 -0.297363
# 3  -0.122683   3.704471   0.058888    ...    -0.957502  0.158936 -0.297363
# 4  -0.020174   3.987459   0.215921    ...    -0.951399  0.158936 -0.297363
#
#     AccMinZ   AccMaxX   AccMaxY   AccMaxZ   AccStdX   AccStdY   AccStdZ
# 0 -1.013184  0.512207 -0.086670 -0.862549  0.123149  0.065373  0.041355
# 1 -1.013184  0.577393 -0.095459 -0.860840  0.134762  0.071420  0.048695
# 2 -1.052246  0.577393 -0.072510 -0.860840  0.126432  0.073989  0.053431
# 3 -1.052246  0.577393 -0.072510 -0.860840  0.131485  0.075443  0.052105
# 4 -1.052246  0.577393 -0.072510 -0.851318  0.129924  0.077282  0.059237
#
# [5 rows x 31 columns]
#
# === Número de casos por classe ===
#
# Classe 1: 239
# Classe 2: 288
# Classe 3: 350
# Classe 4: 224

# %% [markdown]
# ### <font color='black'>2 - Analisando Dataset</font>

# %%
print("=== Correlação entre as variáveis ===")
# Identificar correlação entre as variáveis
def plot_corr(dat, size=7):
    corr = dat.corr()    
    fig, ax = plt.subplots(figsize = (size, size))
    ax.matshow(corr)  
    plt.xticks(range(len(corr.columns)), corr.columns) 
    plt.yticks(range(len(corr.columns)), corr.columns)

# Visualizar correlação em uma tabela
dat.corr()
# Out:
# === Correlação entre as variáveis ===
# %%
# Criar gráfico
plot_corr(dat)

# %%
# plt.figure(figsize=(15, 10))
# plt.grid(True)
# plt.plot(dat['AccY'], label='AccY')
# plt.plot(dat['AccMeanY'], label='AccMeanY')
# plt.legend(loc=2)

# %% [markdown]
# ### <font color='black'>3 - Pré-Processamento</font>

# %%
'''
Verificar Dataset
'''
print("=== Valores nulos? ===")

# Verificar se existe valores nulos
print(dat.isnull().values.any())
print("")
# Out:
# === Valores nulos? ===
# False

# %%
#arquivo externo (pre-processamento)

# %% [markdown]
# ### <font color='black'>4 - Separando (Treinamento/Teste)</font>

# %%
'''
Criando objetos
'''
# X (atributos) | Y (Classe)
X = dat.drop('Class', axis=1).values
Y = dat['Class'].values

print("=== X ===")
print(X)
print("")
print("=== Y ===")
print(Y)
# Out:
# === X ===
# [[-1.35877863  5.5648855   0.19847328 ...  0.12314896  0.06537296
#    0.04135512]
#  [ 1.28244275  0.40458015  1.19847328 ...  0.13476227  0.07142048
#    0.04869458]
#  [-0.23664122  0.73282443  1.45038168 ...  0.12643205  0.07398906
#    0.05343141]
#  ...
#  [-1.0610687   4.53435115  1.18320611 ...  0.21711657  0.18287939
#    0.04362098]
#  [-1.01526718  5.25954198  0.65648855 ...  0.21712547  0.18287928
#    0.04531721]
#  [-0.8778626   4.48854962  0.04580153 ...  0.2182568   0.18062509
#    0.04571726]]
#
# === Y ===
# [1 1 1 ... 4 4 4]

# %%
'''
Divisão de conjunto de treinamento e teste.

Treinamento - 70% | Teste - 30%
'''

print("-> Conjunto Treinamento e Teste: (70% e 30%)\n")

models = ["Random Forest", "SVM", "Naive Bayes", "KNN (k=10)"]
model_scores = []

#Dividindo dataset em treinamento e teste
split_test_size = 0.30
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=split_test_size, random_state=42)
# Out:
# -> Conjunto Treinamento e Teste: (70% e 30%)

# %%
'''
Random Forest
'''

# %%
'''
Random Forest
'''
from sklearn import metrics

#Criando modelo Random Forest
model_rf = RandomForestClassifier(n_estimators=4, criterion='entropy', random_state = 0)
model_rf.fit(X_train, Y_train.ravel())

# Verificando nos dados de teste
#Resultado - Random Forest
print("---------------------------")
print("- Random Forest:          -")
print("---------------------------")
result = model_rf.score(X_test, Y_test)
print("Accuracy: %.2f%%" % (result*100.0))
print('\n')
model_scores.append(result*100.0)

rf_predict_test = model_rf.predict(X_test)

print("=== Confusion Matrix ===")
print(confusion_matrix(Y_test, rf_predict_test))
print('\n')

print("=== Classification Report ===")
print(classification_report(Y_test, rf_predict_test))
print('\n')
# Out:
# ---------------------------
# - Random Forest:          -
# ---------------------------
# Accuracy: 99.70%
#
#
# === Confusion Matrix ===
# [[ 68   0   0   0]
#  [  0  93   0   0]
#  [  0   0 112   0]
#  [  0   0   1  57]]
#
#
# === Classification Report ===
#              precision    recall  f1-score   support
#
#           1       1.00      1.00      1.00        68
#           2       1.00      1.00      1.00        93
#           3       0.99      1.00      1.00       112
#           4       1.00      0.98      0.99        58
#
# avg / total       1.00      1.00      1.00       331

# %%
'''
SVM
'''
model_svm = svm.SVC(kernel='linear')
model_svm.fit(X_train, Y_train)

# Verificando nos dados de teste
#Resultado - SVM
print("---------------------------")
print("- SVM:          -")
print("---------------------------")
result = model_svm.score(X_test, Y_test)
print("Accuracy: %.2f%%" % (result*100.0))
print('\n')
model_scores.append(result*100.0)

rf_predict_test = model_svm.predict(X_test)

print("=== Confusion Matrix ===")
print(confusion_matrix(Y_test, rf_predict_test))
print('\n')

print("=== Classification Report ===")
print(classification_report(Y_test, rf_predict_test))
print('\n')
# Out:
# ---------------------------
# - SVM:          -
# ---------------------------
# Accuracy: 95.17%
#
#
# === Confusion Matrix ===
# [[ 66   0   2   0]
#  [  0  91   2   0]
#  [  8   0 104   0]
#  [  4   0   0  54]]
#
#
# === Classification Report ===
#              precision    recall  f1-score   support
#
#           1       0.85      0.97      0.90        68
#           2       1.00      0.98      0.99        93
#           3       0.96      0.93      0.95       112
#           4       1.00      0.93      0.96        58
#
# avg / total       0.96      0.95      0.95       331

# %%
'''
Naive Bayes
'''
model_nb = GaussianNB()
model_nb.fit(X_train, Y_train.ravel())

#Resultado - Naive Bayes
print("---------------------------")
print("- Naive Bayes:            -")
print("---------------------------")
result = model_nb.score(X_test, Y_test)
print("Accuracy: %.2f%%" % (result*100.0))
print('\n')
model_scores.append(result*100.0)

rf_predict_test = model_nb.predict(X_test)

print("=== Confusion Matrix ===")
print(confusion_matrix(Y_test, rf_predict_test))
print('\n')

print("=== Classification Report ===")
print(classification_report(Y_test, rf_predict_test))
print('\n')
# Out:
# ---------------------------
# - Naive Bayes:            -
# ---------------------------
# Accuracy: 91.54%
#
#
# === Confusion Matrix ===
# [[66  0  2  0]
#  [ 2 91  0  0]
#  [23  0 89  0]
#  [ 1  0  0 57]]
#
#
# === Classification Report ===
#              precision    recall  f1-score   support
#
#           1       0.72      0.97      0.82        68
#           2       1.00      0.98      0.99        93
#           3       0.98      0.79      0.88       112
#           4       1.00      0.98      0.99        58
#
# avg / total       0.93      0.92      0.92       331

# %%
'''
KNN
'''
# Valores de K
K = range(1,11)

# Teste dos modelos
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,Y_train)
    print(k, knn.score(X_test,Y_test))
# Out:
# 1 0.9395770392749244
# 2 0.9395770392749244
# 3 0.9395770392749244
# 4 0.9305135951661632
# 5 0.9395770392749244
# 6 0.9274924471299094
# 7 0.9335347432024169
# 8 0.9395770392749244
# 9 0.9335347432024169
# 10 0.9335347432024169

# %%
model_knn = KNeighborsClassifier(n_neighbors=3)
model_knn.fit(X_train,Y_train)


#Resultado - KNN
print("---------------------------")
print("- KNN:            -")
print("---------------------------")
result = model_knn.score(X_test, Y_test)
print("Accuracy: %.2f%%" % (result*100.0))
print('\n')
model_scores.append(result*100.0)

rf_predict_test = model_knn.predict(X_test)

print("=== Confusion Matrix ===")
print(confusion_matrix(Y_test, rf_predict_test))
print('\n')

print("=== Classification Report ===")
print(classification_report(Y_test, rf_predict_test))
print('\n')
# Out:
# ---------------------------
# - KNN:            -
# ---------------------------
# Accuracy: 93.96%
#
#
# === Confusion Matrix ===
# [[ 62   0   3   3]
#  [  0  91   2   0]
#  [  5   0 102   5]
#  [  2   0   0  56]]
#
#
# === Classification Report ===
#              precision    recall  f1-score   support
#
#           1       0.90      0.91      0.91        68
#           2       1.00      0.98      0.99        93
#           3       0.95      0.91      0.93       112
#           4       0.88      0.97      0.92        58
#
# avg / total       0.94      0.94      0.94       331

# %%
'''Comparação entre os Algoritmos
'''
for i in range(len(model_scores)):
    print("%.2f%% (%s)" % (model_scores[i], models[i]))
sns.barplot(x=[m for m in models], y=model_scores, color="salmon", saturation=.6);
plt.ylabel('Score')
plt.show()
# Out:
# 99.70% (Random Forest)
# 95.17% (SVM)
# 91.54% (Naive Bayes)
# 93.96% (KNN (k=10))

# %% [markdown]
# ### <font color='black'>4 - Separando (Validação Cruzada)</font>

# %%
# '''
# Criando objetos
# '''
# # X (atributos) | Y (Classe)
# X = dat.drop('Class', axis=1).values
# Y = dat['Class'].values

# print("=== X ===")
# print(X)
# print("")
# print("=== Y ===")
# print(Y)

# %%
# '''
# Validação Cruzada K-Fold

# K=10
# '''
# print("-> Validação Cruzada K-Fold\n")

# k=12

# %%
# '''
# Random Forest
# '''
# #Criando modelo Random Forest
# model_kfold = RandomForestClassifier(random_state = 42)

# #Cross-Validation
# #kfold = KFold(n_splits=10, random_state=0)
# results_kfold = cross_val_score(model_kfold, X, Y, cv=k)

# #Resultado - Random Forest
# print("---------------------------")
# print("- Random Forest:          -")
# print("---------------------------")
# print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0)) 

# print("=== All AUC Scores ===")
# print(results_kfold)
# print('\n')

# print("=== Mean AUC Score ===")
# print("Mean AUC Score - Random Forest: ", results_kfold.mean())

# %% [markdown]
# ### <font color='black'>5 - Salvando Modelo</font>

# %%
#Parâmetros de configuração
model = model_rf
filename = 'modelo.pkl'

# %%
#Salava o modelo
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ### <font color='black'>6 - Fazendo Previsões com o Modelo Treinado 1</font>

# %%
# #Parâmetros de entrada
# dic = {"GYROX": -1.961832,  "GYROY": 2.358779,  "GYROZ": 8.893130,  "ACCX": 0.472900,  "ACCY": -0.431152,  "ACCZ": -0.873535}

# filename = 'modelo.pkl'

# %%
# loaded_model = pickle.load(open(filename,'rb'))

# #Cria Array e 
# a = np.array([list(dic.values())])
# prediction = loaded_model.predict(a)[0]

# %%
# print(prediction)

# %% [markdown]
# ### <font color='black'>6 - Fazendo Previsões com o Modelo Treinado 2</font>

# %%
filename = 'modelo.pkl'

# %%
loaded_model = pickle.load(open(filename, 'rb'))

i = 4

result = loaded_model.predict(X_test[i].reshape(1, -1))
#result = loaded_model.predict(X_test)
print("Class (Previsão) = " + str(result))

print("\n\n")

print("Class Dataset:")
print(dat.loc[(dat['GyroX'] == X_test[i][0]) & (dat['GyroY'] == X_test[i][1]) & (dat['GyroZ'] == X_test[i][2])]['Class'])
# Out:
# Class (Previsão) = [2]
#
#
#
# Class Dataset:
# 244    2
# Name: Class, dtype: int64
